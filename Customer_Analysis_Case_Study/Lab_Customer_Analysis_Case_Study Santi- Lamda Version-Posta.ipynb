# %% [markdown]
# ##Lab_Customer_Analysis_Case_Study

# %%
#Aggregate the data into one Data Frame using Pandas.
import numpy as np
import pandas as pd

file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv') 

#Aggregate the data into one Data Frame using Pandas.
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv') 

file1 = file1.rename(columns={'ST':'state','GENDER':'gender'})
file2 = file2.rename(columns={'ST':'state','GENDER':'gender'})
file3 = file3.rename(columns={'State':'state','Gender':'gender'})

#Pay attention that files may have different names for the same column. therefore, make sure that you unify the columns names before concating them.
file4 = pd.concat([file1, file2, file3]) 

#Standardizing header names
def lower_case_column_names(file4):
    file4.columns=[i.lower() for i in file4.columns]
    return file4
file4=lower_case_column_names(file4)

#Removing duplicates
file4.drop_duplicates()

#Deleting and rearranging columns: delete the column customer as it is only a unique identifier for each row of data

# otra forma: file4 = file4.drop('customer', axis=1)
file4.drop('customer', axis=1, inplace =True)

# %% [markdown]
# Working with data types: Check the data types of all the columns and fix the incorrect ones
#
# (for ex. customer lifetime value and number of open complaints ).
#
# Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.

# %%
#How to finde the datatype and quantity of data in a column 
print(file4['customer lifetime value'].apply(type).value_counts())
# Out:
# <class 'float'>    10014
# <class 'str'>       2060
# Name: customer lifetime value, dtype: int64

# %%
# Sacar el %

file4['customer lifetime value']=file4['customer lifetime value'].apply(lambda x: x.replace('%', '') if isinstance(x, str) else x)
file4
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %% [markdown]
# Clean the number of open complaints and extract the middle number which is changing between records.

# %% [markdown]
# #How to finde the datatype and quantity of data in a column
# file4['number of open complaints'].apply(type)
#
# #file4['number of open complaints'].info()
#
# #Shows the data in the column
# for i in file4['number of open complaints']:
#     print(i)

# %%
x="1/0/00"
if isinstance(x,str):
    print(x.split('/')[1])
else:
    print(x)
# Out:
# 0

# %%
# Extract the middle number with lambda

file4['number of open complaints']=file4['number of open complaints'].apply(lambda x: x.split('/')[1] if isinstance(x, str) else x)

file4
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
# extract the middle number

# List with the str of 'number of open complaints'
file4_str = []

for i in file4['number of open complaints'].tolist():
    if isinstance(i,str):
        file4_str.append(i)

# %%
#list with split values
            
for value in file4_str:
    file4_split = value.split("/") 

print(file_split)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 6>()
#       3 for value in file4_str:
#       4     file4_split = value.split("/")
# ----> 6 print(file_split)
#
# NameError: name 'file_split' is not defined

# %%
#list with only the middle 0

for value in file4_split:
    if isinstance(value, file_split[1]):
        file4_final.append(value)
        
print(file4_final)

# %%
#How to finde the datatype and quantity of data in a column 
print(file4['number of open complaints'].apply(type).value_counts())

# %%
buscar los nans de manera eficiente. encontrar nans en varias columnas de una vez, en codigo corto
