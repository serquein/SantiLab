# %% [markdown]
# ##Lab_Customer_Analysis_Case_Study

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Aggregate the data into one Data Frame using Pandas.

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %%
#otra forma:
#file1= file1.rename(columns={file1.columns[1]: 'state'})


new_colums_names = {'ST':'state','GENDER':'gender'}

file1 = file1.rename(columns={'ST':'state','GENDER':'gender'})
file2 = file2.rename(columns={'ST':'state','GENDER':'gender'})
file3 = file3.rename(columns={'State':'state','Gender':'gender'})

# %% [markdown]
# Pay attention that files may have different names for the same column. therefore, make sure that you unify the columns names before concating them.

# %%
file4 = pd.concat([file1, file2, file3]) 
file4
# Out:
#      Customer       state gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# Standardizing header names

# %%
def lower_case_column_names(file4):
    file4.columns=[i.lower() for i in file4.columns]
    return file4
file4=lower_case_column_names(file4)

file4
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
file4.drop_duplicates()
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %% [markdown]
# Deleting and rearranging columns: delete the column customer as it is only a unique identifier for each row of data

# %%
file4=file4.drop('customer', axis=1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [103], in <cell line: 1>()
# ----> 1 file4=file4.drop('customer', axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
# ...

# %% [markdown]
# Removing duplicates

# %%
file4.drop_duplicates()
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %% [markdown]
# Working with data types: Check the data types of all the columns and fix the incorrect ones
#
# (for ex. customer lifetime value and number of open complaints ).
#
# Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.

# %%
#Check the data types of all the columns
file4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 1.0+ MB

# %%
#cambiar las int(object) en float de las columnas:
#costumer lifetime value & number of open complaints
file4['customer lifetime value'] = pd.to_numeric(file4['customer lifetime value'], errors='coerce')
file4['number of open complaints '] = pd.to_numeric(file4['number of open complaints'], errors='coerce')

# %%
#find the NaN values
corrupted_rows_indices=list(file4[file4['customer lifetime value'].isnull()].index)
corrupted_rows_indices
file4.iloc[corrupted_rows_indices,:]
# Out:
#           state gender             education  customer lifetime value  \
# 0    Washington    NaN                Master                      NaN
# 1       Arizona      F              Bachelor                      NaN
# 2        Nevada      F              Bachelor                      NaN
# 3    California      M              Bachelor                      NaN
# 4    Washington      M  High School or Below                      NaN
# ..          ...    ...                   ...                      ...
# 991      Oregon      F  High School or Below                      NaN
# 992     Arizona      M              Bachelor                      NaN
# 993     Arizona      M                Doctor                      NaN
# 994        Cali      F              Bachelor                      NaN
# 995      Oregon      F  High School or Below                      NaN
#
#       income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
#

# %%
#remove the '%'
#convert to an int
#necesito identificar la cantidad de NaN en la columna para evaluar si los borro o no, si vale la pena hacer el cambio.
file4['customer lifetime value'] = file4['customer lifetime value'].str.replace('%', '').astype(int) 

file4
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [54], in <cell line: 4>()
#       1 #remove the '%'
#       2 #convert to an int
#       3 #necesito identificar la cantidad de NaN en la columna para evaluar si los borro o no, si vale la pena hacer el cambio.
# ----> 4 file4['customer lifetime value'] = file4['customer lifetime value'].str.replace('%', '').astype(int)
#       6 file4
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# ...

# %% [markdown]
# Clean the number of open complaints and extract the middle number which is changing between records.

# %%
#Cleaning
# handle missing or invalid values
file4_OpenComplains = file4.dropna(subset=['open complaints'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 3>()
#       1 #Cleaning
#       2 # handle missing or invalid values
# ----> 3 file4_OpenComplains = file4.dropna(subset=['open complaints'])
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6002, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    6000     check = indices == -1
#    6001     if check.any():
# -> 6002         raise KeyError(np.array(subset)[check].tolist())
# ...

# %%
Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns
