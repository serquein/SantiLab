# %% [markdown]
# # Santi's Favourite Hollidays

# %% [markdown]
# <span style='color:orange'> The purpose of this notebook is to tell the wold about Santi's hollidays </span>

# %%
#I used "imput" so the person can enter my name
imput= ("Please enter the person's name: ")
print(imput)
# Out:
# Please enter the person's name:

# %% [markdown]
# ![Santi%20copa.jpg](attachment:Santi%20copa.jpg)

# %% [markdown]
# **This are the Maldivas**

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/3FM1waTeTDE?controls=0"
# </iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/3FM1waTeTDE?controls=0"
# </iframe>

# %% [markdown]
# ![Maldivas.jpg](attachment:Maldivas.jpg)

# %% [markdown]
# - Play beach Volley
# - Play the guitar
# - Play football
